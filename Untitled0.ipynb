# %% [markdown]
# <a href="https://colab.research.google.com/github/Suchada2000/BSC_DPDM23/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lode data

# %%
import pandas as pd

# %% [markdown]
# # Load Excel from Gdrive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_from_gdrive = pd.read_excel('/content/drive/MyDrive/bsc_dpdm23_data/2563.xls')

# %%
data_from_gdrive
# Out:
#      Unnamed: 0          Unnamed: 1                               Unnamed: 2  \
# 0           NaN                 NaN                                      NaN
# 1    เลขที่คำขอ  เลขที่บัตรส่งเสริม                        ชื่อบริษัทภาษาไทย
# 2        610707    62-0422-1-04-1-0  กรุงเทพ ไดอ์แคสซ์ติ้ง แอนด์ อินแจ๊กชั่น
# 3        620660    63-0107-1-00-1-0                        เจ้าพระยา คาร์บอน
# 4        610182    63-0101-1-00-1-0                        อาร์ต ออฟ เบคกิ้ง
# ..          ...                 ...                                      ...
# 657     E630369    63-0669-1-00-0-0  อีเลคโทรลักซ์ โปรเฟสชั่นแนล (ประเทศไทย)
# 658     E630401    63-0682-1-00-1-0                            โกลว์ พลังงาน
# 659     E630277    63-0666-1-03-1-0         ยูนิค อุตสาหกรรมพลาสติก (แม่สอด)
# 660      610552    63-0676-1-00-1-0                   ไอชิน เอไอ (ประเทศไทย)
# 661     E630269    63-0668-1-00-1-0     เอ็มเอ็มซี อีเล็คโทรนิคส์ (ไทยแลนด์)
#
# ...

# %% [markdown]
# # Load Gsheets

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds,_ = default()

gc = gspread.authorize(creds)

# %%
gsht = gc.open_by_key('/content/drive/MyDrive/bsc_dpdm23_data/2563.gsheet')

# %%
worksheet2 = gsht.worksheet("มิ.ย. 2563")
rows = worksheet2.get_all_values()
nayooH = pd.DataFrame.from_records(row)
nayooH2.column = nayooH.iloc[0]
# Out:
# ---------------------------------------------------------------------------
# APIError                                  Traceback (most recent call last)
# <ipython-input-11-e369c42b75cb> in <cell line: 1>()
# ----> 1 worksheet2 = gsht.worksheet("มิ.ย. 2563")
#       2 rows = worksheet2.get_all_values()
#       3 nayooH = pd.DataFrame.from_records(row)
#       4 nayooH2.column = nayooH.iloc[0]
#
# /usr/local/lib/python3.10/dist-packages/gspread/models.py in worksheet(self, title)
#     312
#     313         """
# --> 314         sheet_data = self.fetch_sheet_metadata()
#     315         try:
#     316             item = finditem(
#
# /usr/local/lib/python3.10/dist-packages/gspread/models.py in fetch_sheet_metadata(self, params)
#     261         url = SPREADSHEET_URL % self.id
#     262
# --> 263         r = self.client.request('get', url, params=params)
#     264
#     265         return r.json()
#
# ...

# %%
data_from_gsheets.head()

# %%
data_from_gsheets.column = data_from_gdrive.iloc[2] #rowhead set header
data_from_gsheets = data_from_gsheets.iloc[3:].reset_index().iloc[:,1:] #เริ่มrow แล้วก็ตัดแถวแรกออก skip rows
data_from_gsheets.head()

# %% [markdown]
# # Basic stats

# %%
data_from_gsheets.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-a986d53e78fc> in <cell line: 1>()
# ----> 1 data_from_gsheets.describe()
#
# NameError: name 'data_from_gsheets' is not defined

# %% [markdown]
# # visualization

# %% [markdown]
# # Distance - Simalarity

# %% [markdown]
# # z - score
