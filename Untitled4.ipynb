# %% [markdown]
# <a href="https://colab.research.google.com/github/Suchada2000/BSC_DPDM23/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![quiz9.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![quiz(9).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![quiz-9.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![quiz_9.jpg](data:image/jpeg;base64,...)
